# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme()

# %%
tournaments_2000_2009 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/1_tournaments/tournaments_2000-2009.csv', header=None)

# %%
tournaments_2000_2009.head()
# Out:
#           0   1    2         3     4         5         6           7     8   \
# 0   2000-451   1  NaN      Doha   451      doha      Doha  2000.01.03  2000
# 1   2000-891   2  NaN   Chennai   891   chennai   Chennai  2000.01.03  2000
# 2  2000-7308   3  NaN  Adelaide  7308  adelaide  Adelaide  2000.01.03  2000
# 3   2000-301   4  NaN  Auckland   301  auckland  Auckland  2000.01.10  2000
# 4   2000-338   5  NaN    Sydney   338    sydney    Sydney  2000.01.10  2000
#
#    9   ...               21    22              23  \
# 0   1  ...  fabrice-santoro  s424    Mark Knowles
# 1   1  ...   jerome-golmard  g319  Julien Boutter
# 2   1  ...   lleyton-hewitt  h432  Mark Woodforde
# 3   1  ...    magnus-norman  n250  Ellis Ferreira
# 4   1  ...   lleyton-hewitt  h432  Mark Woodforde
#
#                                          24              25    26  \
# 0    /en/players/mark-knowles/k171/overview    mark-knowles  k171
# 1  /en/players/julien-boutter/b599/overview  julien-boutter  b599
# ...

# %%
tournaments_col_names = ['tourney_year_id'
,'tourney_order'
,'tourney_type'
,'tourney_name'
,'tourney_id'
,'tourney_slug'
,'tourney_location'
,'tourney_date'
,'year'
,'tourney_month'
,'tourney_day'
,'tourney_singles_draw'
,'tourney_doubles_draw'
,'tourney_conditions'
,'tourney_surface'
,'tourney_fin_commit_raw'
,'currency'
,'tourney_fin_commit'
,'tourney_url_suffix'
,'singles_winner_name'
,'singles_winner_url'
,'singles_winner_player_slug'
,'singles_winner_player_id'
,'doubles_winner_1_name'
,'doubles_winner_1_url'
,'doubles_winner_1_player_slug'
,'doubles_winner_1_player_id'
,'doubles_winner_2_name'
,'doubles_winner_2_url'
,'doubles_winner_2_player_slug'
,'doubles_winner_2_player_id']

# %%
dict_for_renaming = {k: v for k, v in zip(tournaments_2000_2009.columns, tournaments_col_names)}

# %%
tournaments_2000_2009 = tournaments_2000_2009.rename(dict_for_renaming, axis=1)

# %%
tournaments_2000_2009.head()
# Out:
#   tourney_year_id  tourney_order tourney_type tourney_name  tourney_id  \
# 0        2000-451              1          NaN         Doha         451
# 1        2000-891              2          NaN      Chennai         891
# 2       2000-7308              3          NaN     Adelaide        7308
# 3        2000-301              4          NaN     Auckland         301
# 4        2000-338              5          NaN       Sydney         338
#
#   tourney_slug tourney_location tourney_date  year  tourney_month  ...  \
# 0         doha             Doha   2000.01.03  2000              1  ...
# 1      chennai          Chennai   2000.01.03  2000              1  ...
# 2     adelaide         Adelaide   2000.01.03  2000              1  ...
# 3     auckland         Auckland   2000.01.10  2000              1  ...
# 4       sydney           Sydney   2000.01.10  2000              1  ...
#
#    singles_winner_player_slug  singles_winner_player_id  \
# ...

# %%
tournaments_2000_2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tourney_year_id               683 non-null    object
#  1   tourney_order                 683 non-null    int64
#  2   tourney_type                  193 non-null    object
#  3   tourney_name                  683 non-null    object
#  4   tourney_id                    683 non-null    int64
#  5   tourney_slug                  683 non-null    object
#  6   tourney_location              673 non-null    object
#  7   tourney_date                  683 non-null    object
#  8   year                          683 non-null    int64
#  9   tourney_month                 683 non-null    int64
#  10  tourney_day                   683 non-null    int64
#  11  tourney_singles_draw          683 non-null    int64
# ...

# %%
tournaments_2010_2019 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/1_tournaments/tournaments_2010-2019.csv', header=None)

# %%
tournaments_2010_2019
# Out:
#             0   1                2                       3     4   \
# 0     2010-339   1          ATP 250                Brisbane   339
# 1     2010-451   2          ATP 250                    Doha   451
# 2     2010-891   3          ATP 250                 Chennai   891
# 3     2010-338   4          ATP 250                  Sydney   338
# 4     2010-301   5          ATP 250                Auckland   301
# ..         ...  ..              ...                     ...   ...
# 663   2019-337  64          ATP 500                  Vienna   337
# 664   2019-328  65          ATP 500                   Basel   328
# 665   2019-352  66     Masters 1000  ATP Masters 1000 Paris   352
# 666  2019-7696  67  Next Gen Finals     Next Gen ATP Finals  7696
# 667   2019-605  68       ATP Finals        Nitto ATP Finals   605
#
#                       5                      6           7     8   9   ...  \
# 0               brisbane               Brisbane  2010.01.03  2010   1  ...
# ...

# %%
tournaments_2010_2019 = tournaments_2010_2019.rename(dict_for_renaming, axis=1)

# %%
tournaments_2010_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tourney_year_id               668 non-null    object
#  1   tourney_order                 668 non-null    int64
#  2   tourney_type                  663 non-null    object
#  3   tourney_name                  668 non-null    object
#  4   tourney_id                    668 non-null    int64
#  5   tourney_slug                  668 non-null    object
#  6   tourney_location              667 non-null    object
#  7   tourney_date                  668 non-null    object
#  8   year                          668 non-null    int64
#  9   tourney_month                 668 non-null    int64
#  10  tourney_day                   668 non-null    int64
#  11  tourney_singles_draw          668 non-null    int64
# ...

# %%
tournaments_2020_2022 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/1_tournaments/tournaments_2020-2022.csv', header=None)

# %%
tournaments_2020_2022
# Out:
#             0   1                2                                    3   \
# 0    2020-8888   1          ATP Cup                              ATP Cup
# 1     2020-451   2          ATP 250                                 Doha
# 2    2020-8998   3          ATP 250                             Adelaide
# 3     2020-301   4          ATP 250                             Auckland
# 4     2020-580   5       Grand Slam                      Australian Open
# ..         ...  ..              ...                                  ...
# 217   2022-337  67          ATP 500                      Erste Bank Open
# 218   2022-328  68          ATP 500                  Swiss Indoors Basel
# 219   2022-352  69     Masters 1000                  Rolex Paris Masters
# 220  2022-7696  70  Next Gen Finals  Intesa Sanpaolo Next Gen ATP Finals
# 221   2022-605  71       ATP Finals                     Nitto ATP Finals
#
#        4                                    5   \
# ...

# %%
tournaments_2020_2022 = tournaments_2020_2022.rename(dict_for_renaming, axis=1)

# %%
tournaments_2000_2022 = pd.concat([tournaments_2000_2009, tournaments_2010_2019, tournaments_2020_2022], axis=0)

# %%
tournaments_2000_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1573 entries, 0 to 221
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tourney_year_id               1573 non-null   object
#  1   tourney_order                 1573 non-null   int64
#  2   tourney_type                  1076 non-null   object
#  3   tourney_name                  1573 non-null   object
#  4   tourney_id                    1573 non-null   int64
#  5   tourney_slug                  1573 non-null   object
#  6   tourney_location              1562 non-null   object
#  7   tourney_date                  1573 non-null   object
#  8   year                          1573 non-null   int64
#  9   tourney_month                 1573 non-null   int64
#  10  tourney_day                   1573 non-null   int64
#  11  tourney_singles_draw          1573 non-null   int64
# ...

# %%
tournaments_2000_2022['tourney_year_id'].value_counts()
# Out:
# 2000-451    1
# 2015-314    1
# 2015-414    1
# 2015-439    1
# 2015-316    1
#            ..
# 2007-315    1
# 2007-316    1
# 2007-314    1
# 2007-540    1
# 2022-605    1
# Name: tourney_year_id, Length: 1573, dtype: int64

# %%
len(tournaments_2000_2022['tourney_year_id'].unique())
# Out:
# 1573

# %%
tournaments_2000_2022.to_csv('Sources/atp-world-tour-tennis-data-master/csv/1_tournaments/tournaments_2000_2022.csv')

# %%
match_scores_2000_2009 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/2_match_scores/match_scores_2000-2009.csv', header=None)

# %%
match_scores_col_names = ['tourney_year_id',
'tourney_order',
'tourney_name',
'tourney_slug',
'tourney_url_suffix',
'start_date',
'start_year',
'start_month',
'start_day',
'end_date',
'end_year',
'end_month',
'end_day',
'currency',
'prize_money',
'match_index',
'tourney_round_name',
'round_order',
'match_order',
'winner_name',
'winner_player_id',
'winner_slug',
'loser_name',
'loser_player_id',
'loser_slug',
'winner_seed',
'loser_seed',
'match_score_tiebreaks',
'winner_sets_won',
'loser_sets_won',
'winner_games_won',
'loser_games_won',
'winner_tiebreaks_won',
'loser_tiebreaks_won',
'match_id',
'match_stats_url_suffix']

# %%
dict_for_renaming2 = {k: v for k, v in zip(match_scores_2000_2009.columns, match_scores_col_names)}

# %%
match_scores_2000_2009 = match_scores_2000_2009.rename(dict_for_renaming2, axis=1)

# %%
match_scores_2000_2009
# Out:
#       tourney_year_id  tourney_order tourney_name tourney_slug  \
# 0            2000-451              1         Doha         doha
# 1            2000-451              1         Doha         doha
# 2            2000-451              1         Doha         doha
# 3            2000-451              1         Doha         doha
# 4            2000-451              1         Doha         doha
# ...               ...            ...          ...          ...
# 34217        2009-605             66   ATP Finals   atp-finals
# 34218        2009-605             66   ATP Finals   atp-finals
# 34219        2009-605             66   ATP Finals   atp-finals
# 34220        2009-605             66   ATP Finals   atp-finals
# 34221        2009-605             66   ATP Finals   atp-finals
#
#                                    tourney_url_suffix  start_date  start_year  \
# 0            /en/scores/archive/doha/451/2000/results  2000.01.03      2000.0
# ...

# %%
match_scores_2010_2019 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/2_match_scores/match_scores_2010-2019.csv', header=None)
match_scores_2010_2019 = match_scores_2010_2019.rename(dict_for_renaming2, axis=1)

match_scores_2020_2022 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/2_match_scores/match_scores_2020-2022.csv', header=None)
match_scores_2020_2022 = match_scores_2020_2022.rename(dict_for_renaming2, axis=1)

# %%
match_scores_2000_2022 = pd.concat([match_scores_2000_2009, match_scores_2010_2019, match_scores_2020_2022], axis=0)

# %%
match_scores_2000_2022
# Out:
#      tourney_year_id  tourney_order                         tourney_name  \
# 0           2000-451              1                                 Doha
# 1           2000-451              1                                 Doha
# 2           2000-451              1                                 Doha
# 3           2000-451              1                                 Doha
# 4           2000-451              1                                 Doha
# ...              ...            ...                                  ...
# 9717       2022-7696             70  Intesa Sanpaolo Next Gen ATP Finals
# 9718       2022-7696             70  Intesa Sanpaolo Next Gen ATP Finals
# 9719       2022-7696             70  Intesa Sanpaolo Next Gen ATP Finals
# 9720        2022-605             71                     Nitto ATP Finals
# 9721        2022-605             71                     Nitto ATP Finals
#
#                              tourney_slug  \
# 0                                    doha
# ...

# %%
match_scores_2000_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86771 entries, 0 to 9721
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tourney_year_id         86771 non-null  object
#  1   tourney_order           86771 non-null  int64
#  2   tourney_name            86771 non-null  object
#  3   tourney_slug            86771 non-null  object
#  4   tourney_url_suffix      86771 non-null  object
#  5   start_date              86159 non-null  object
#  6   start_year              86159 non-null  float64
#  7   start_month             86159 non-null  float64
#  8   start_day               86159 non-null  float64
#  9   end_date                86159 non-null  object
#  10  end_year                86159 non-null  float64
#  11  end_month               86159 non-null  float64
#  12  end_day                 86159 non-null  float64
#  13  currency                86159 non-null  object
# ...

# %%
len(match_scores_2000_2022['tourney_year_id'].unique())
# Out:
# 1509

# %%
match_scores_2000_2022['match_index'].value_counts()
# Out:
# 2021.0    3762
# 2022.0    2975
# 2020.0    1895
# MS001     1323
# MS019     1315
#           ...
# QS104       47
# QS060       46
# QS063       46
# QS071       46
# MS000        2
# Name: match_index, Length: 255, dtype: int64

# %%
match_stats_col_names = ['match_id',
'tourney_slug',
'match_stats_url_suffix',
'match_time',
'match_duration',
'winner_slug',
'winner_serve_rating',
'winner_aces',
'winner_double_faults',
'winner_first_serves_in',
'winner_first_serves_total',
'winner_first_serve_points_won',
'winner_first_serve_points_total',
'winner_second_serve_points_won',
'winner_second_serve_points_total',
'winner_break_points_saved',
'winner_break_points_serve_total',
'winner_service_games_played',
'winner_return_rating',
'winner_first_serve_return_won',
'winner_first_serve_return_total',
'winner_second_serve_return_won',
'winner_second_serve_return_total',
'winner_break_points_converted',
'winner_break_points_return_total',
'winner_return_games_played',
'winner_service_points_won',
'winner_service_points_total',
'winner_return_points_won',
'winner_return_points_total',
'winner_total_points_won',
'winner_total_points_total',
'loser_slug',
'loser_serve_rating',
'loser_aces',
'loser_double_faults',
'loser_first_serves_in',
'loser_first_serves_total',
'loser_first_serve_points_won',
'loser_first_serve_points_total',
'loser_second_serve_points_won',
'loser_second_serve_points_total',
'loser_break_points_saved',
'loser_break_points_serve_total',
'loser_service_games_played',
'loser_return_rating',
'loser_first_serve_return_won',
'loser_first_serve_return_total',
'loser_second_serve_return_won',
'loser_second_serve_return_total',
'loser_break_points_converted',
'loser_break_points_return_total',
'loser_return_games_played',
'loser_service_points_won',
'loser_service_points_total',
'loser_return_points_won',
'loser_return_points_total',
'loser_total_points_won',
'loser_total_points_total']

# %%
match_stats_2000 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2000.csv', header=None)
match_stats_2001 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2001.csv', header=None)
match_stats_2002 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2002.csv', header=None)
match_stats_2003 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2003.csv', header=None)
match_stats_2004 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2004.csv', header=None)
match_stats_2005 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2005.csv', header=None)
match_stats_2006 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2006.csv', header=None)
match_stats_2007 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2007.csv', header=None)
match_stats_2008 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2008.csv', header=None)
match_stats_2009 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2009.csv', header=None)
match_stats_2010 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2010.csv', header=None)
match_stats_2011 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2011.csv', header=None)
match_stats_2012 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2012.csv', header=None)
match_stats_2013 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2013.csv', header=None)
match_stats_2014 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2014.csv', header=None)
match_stats_2015 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2015.csv', header=None)
match_stats_2016 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2016.csv', header=None)
match_stats_2017 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2017.csv', header=None)
match_stats_2018 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2018.csv', header=None)
match_stats_2019 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2019.csv', header=None)
match_stats_2020 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2020.csv', header=None)
match_stats_2021 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2021.csv', header=None)
match_stats_2022 = pd.read_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2022.csv', header=None)

# %%
dict_for_renaming3 = {k: v for k, v in zip(match_stats_2000.columns, match_stats_col_names)}

# %%
liste = [match_stats_2000,
match_stats_2001,
match_stats_2002,
match_stats_2003,
match_stats_2004,
match_stats_2005,
match_stats_2006,
match_stats_2007,
match_stats_2008,
match_stats_2009,
match_stats_2010,
match_stats_2011,
match_stats_2012,
match_stats_2013,
match_stats_2014,
match_stats_2015,
match_stats_2016,
match_stats_2017,
match_stats_2018,
match_stats_2019,
match_stats_2020,
match_stats_2021,
match_stats_2022]

# %%
match_stats_2000_2022 = pd.concat(liste, axis=0)

# %%
match_stats_2000_2022 = match_stats_2000_2022.rename(dict_for_renaming3, axis=1)

# %%
match_stats_2000_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83429 entries, 0 to 2974
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   match_id                          83429 non-null  object
#  1   tourney_slug                      83429 non-null  object
#  2   match_stats_url_suffix            83429 non-null  object
#  3   match_time                        78064 non-null  object
#  4   match_duration                    78064 non-null  float64
#  5   winner_slug                       78064 non-null  object
#  6   winner_serve_rating               74785 non-null  float64
#  7   winner_aces                       74785 non-null  float64
#  8   winner_double_faults              74785 non-null  float64
#  9   winner_first_serves_in            74785 non-null  float64
#  10  winner_first_serves_total         74785 non-null  float64
# ...

# %%
len(match_stats_2000_2022['match_id'].unique())
# Out:
# 83408

# %%
match_stats_2000_2022['match_id'].value_counts()
# Out:
# 2022-archive-2022-4-3-ke17-pl56           2
# 2022-archive-2022-4-4-n0ae-kb09           2
# 2022-archive-2022-3-9-f724-hg86           2
# 2020-archive-2020-6-2-mc65-kb05           2
# 2021-archive-2021-8-4-d643-bk40           2
#                                          ..
# 2008-328-MS008-5-8-f324-n289              1
# 2008-328-MS005-6-1-l397-b676              1
# 2008-328-MS006-6-2-d683-a511              1
# 2008-328-MS007-6-3-n301-b896              1
# live-scores-archive-2022-1-1-rh16-ag37    1
# Name: match_id, Length: 83408, dtype: int64

# %%
match_stats_2000_2022
# Out:
#                                     match_id  \
# 0               2000-451-MS001-5-1-s424-s636
# 1               2000-451-MS002-4-2-s424-k316
# 2               2000-451-MS003-4-1-s636-e121
# 3               2000-451-MS004-3-4-k316-s572
# 4               2000-451-MS005-3-3-s424-b503
# ...                                      ...
# 2970  live-scores-archive-2022-1-3-s0la-d0co
# 2971  live-scores-archive-2022-1-2-n0ae-a0fc
# 2972  live-scores-archive-2022-1-1-l0bv-p0ct
# 2973  live-scores-archive-2022-1-2-fb98-n409
# 2974  live-scores-archive-2022-1-1-rh16-ag37
#
#                              tourney_slug  \
# 0                                    doha
# 1                                    doha
# 2                                    doha
# 3                                    doha
# 4                                    doha
# ...                                   ...
# 2970  intesa-sanpaolo-next-gen-atp-finals
# 2971  intesa-sanpaolo-next-gen-atp-finals
# ...

# %%
match_stats_2000_2022.to_csv('Sources/atp-world-tour-tennis-data-master/csv/3_match_stats/match_stats_2000_2022.csv')

# %%
match_scores_2000_2022.to_csv('Sources/atp-world-tour-tennis-data-master/csv/2_match_scores/match_scores_2000_2022.csv')

# %%
tournaments_2000_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1573 entries, 0 to 221
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tourney_year_id               1573 non-null   object
#  1   tourney_order                 1573 non-null   int64
#  2   tourney_type                  1076 non-null   object
#  3   tourney_name                  1573 non-null   object
#  4   tourney_id                    1573 non-null   int64
#  5   tourney_slug                  1573 non-null   object
#  6   tourney_location              1562 non-null   object
#  7   tourney_date                  1573 non-null   object
#  8   year                          1573 non-null   int64
#  9   tourney_month                 1573 non-null   int64
#  10  tourney_day                   1573 non-null   int64
#  11  tourney_singles_draw          1573 non-null   int64
# ...

# %%
odds_data_2000 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2000.xls')
odds_data_2001 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2001.xls')
odds_data_2002 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2002.xls')
odds_data_2003 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2003.xls')
odds_data_2004 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2004.xls')
odds_data_2005 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2005.xls')
odds_data_2006 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2006.xls')
odds_data_2007 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2007.xls')
odds_data_2008 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2008.xls')
odds_data_2009 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2009.xls')
odds_data_2010 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2010.xls')
odds_data_2011 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2011.xls')
odds_data_2012 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2012.xls')
odds_data_2013 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2013.xlsx')
odds_data_2014 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2014.xlsx')
odds_data_2015 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2015.xlsx')
odds_data_2016 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2016.xlsx')
odds_data_2017 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2017.xlsx')
odds_data_2018 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2018.xlsx')
odds_data_2019 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2019.xlsx')
odds_data_2020 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2020.xlsx')
odds_data_2021 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2021.xlsx')
odds_data_2022 = pd.read_excel('Sources/tennis-data.co.uk-with-odds/2022.xlsx')
# Out:
# C:\Users\enovap\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\enovap\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\enovap\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\enovap\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
odds_data_2000_2022 = pd.concat([odds_data_2000,
odds_data_2001,
odds_data_2002,
odds_data_2003,
odds_data_2004,
odds_data_2005,
odds_data_2006,
odds_data_2007,
odds_data_2008,
odds_data_2009,
odds_data_2010,
odds_data_2011,
odds_data_2012,
odds_data_2013,
odds_data_2014,
odds_data_2015,
odds_data_2016,
odds_data_2017,
odds_data_2018,
odds_data_2019,
odds_data_2020,
odds_data_2021,
odds_data_2022], axis=0)

# %%
odds_data_2000_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61281 entries, 0 to 2616
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         61281 non-null  int64
#  1   Location    61281 non-null  object
#  2   Tournament  61281 non-null  object
#  3   Date        61281 non-null  datetime64[ns]
#  4   Series      61281 non-null  object
#  5   Court       61281 non-null  object
#  6   Surface     61281 non-null  object
#  7   Round       61281 non-null  object
#  8   Best of     61281 non-null  int64
#  9   Winner      61281 non-null  object
#  10  Loser       61281 non-null  object
#  11  WRank       61261 non-null  object
#  12  LRank       61176 non-null  object
#  13  W1          60953 non-null  float64
#  14  L1          60956 non-null  float64
#  15  W2          60389 non-null  object
#  16  L2          60390 non-null  object
#  17  W3          28572 non-null  object
# ...

# %%
odds_data_2000_2022.to_csv('Sources/tennis-data.co.uk-with-odds/odds_data_2000_2022.csv')
